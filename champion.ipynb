# %%
from last_data import main_data
from champion import json_to_champion

# %%
a = json_to_champion(main_data)

print("""
@base <http://example.org/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix ex: <http://ex.org/>.
@prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
      """)

print("ex:Runeterra a ex:Place .", end="\n\n")
print("ex:Fighter a ex:Tag .")
print("ex:Tank a ex:Tag ." )
print("ex:Mage a ex:Tag .")
print("ex:Assassin a ex:Tag .")
print("ex:Support a ex:Tag .")
print("ex:Marksman a ex:Tag .", end="\n\n")

print("ex:Top a ex:Position .")
print("ex:Mid a ex:Position .")
print("ex:Support a ex:Position .")
print("ex:Bottom a ex:Position .")
print("ex:Jungle a ex:Position .", end="\n\n")

for i in a:
    i.rdf_champ()
# Out:
# @base <http://example.org/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix ex: <http://ex.org/>.
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
#
# ex:Runeterra a ex:Place .
#
# ex:Fighter a ex:Tag .
# ex:Tank a ex:Tag .
# ex:Mage a ex:Tag .
# ex:Assassin a ex:Tag .
# ex:Support a ex:Tag .
# ex:Marksman a ex:Tag .
#
# ex:Top a ex:Position .
# ex:Mid a ex:Position .
# ex:Support a ex:Position .
# ex:Bottom a ex:Position .
# ex:Jungle a ex:Position .
#
# ex:Aatrox a ex:Champion ;
#         ex:primaryPosition ex:Top ;
#         ex:thirdPosition ex: ;
#         ex:region ex:Runeterra ;
#         ex:partype ex:BloodWell ;
#         ex:playStyle ex:Juggernaut ;
#         ex:relation ex:Kayn , ex:Varus , ex:Tryndamere  ;
#         ex:tags ex:Fighter , ex:Tank  ;
#         ex:releaseDate "2013-06-13"^^xsd:date .
#
# ex:Ahri a ex:Champion ;
#         ex:primaryPosition ex:Mid ;
# ...
